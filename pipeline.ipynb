# %%
import psycopg2 
import pandas as pd 
from sqlalchemy import create_engine
import os
import boto3
from io import StringIO, BytesIO

# %%
def list_all_tables(path):
    # List all files in the directory
    files = os.listdir(path)

    return files

# %%
def check_meta_data(path):
    if os.path.exists(path):
        # If CSV file exists, read data from it
        df = pd.read_csv(path)
    else:
        df = pd.DataFrame(columns=['table', 'logging_id'])
        
    return df

# %%
def establish_connection_to_database(user, password, host, port, db):
    # establish connections 
    conn_string = f'postgresql://{user}:{password}@{host}:{port}/{db}'

    db = create_engine(conn_string)
     
    conn = db.connect()

    return conn

# %%
def extracting_data(path):
    print(f"Extacting Data from {path}")
    df = pd.read_csv(path)

    return df

# %%
def dataframe_to_s3(input_datafame, bucket_name, filepath, format):
    import boto3

    # Initialize the S3 client with specific configurations for non-AWS S3-compatible service
    s3 = boto3.client('s3')
    
    if format == 'parquet':
        out_buffer = BytesIO()
        input_datafame.to_parquet(out_buffer, index=False)

    elif format == 'csv':
        out_buffer = StringIO()
        input_datafame.to_parquet(out_buffer, index=False)

    s3.put_object(Bucket=bucket_name, Key=filepath, Body=out_buffer.getvalue())

# %%
def adding_new_columns(dataframe, logging_id):
    dataframe['batch_id'] = logging_id
    dataframe['start_date'] = None
    dataframe['end_date'] = None
    dataframe['is_active'] = None

    return dataframe

# %%
def loading_data(dataframe, table, schemaName):
    user = "postgres"
    password = "admin"
    host = "localhost"
    port = "5432"
    db = "DWH"

    conn = establish_connection_to_database(user, password, host, port, db)

    dataframe.to_sql(table, conn, schema = schemaName, index = False, if_exists = 'replace')

# %%
def ETL(base):
    print("<<<----------------------Fetching All Tables---------------------->>>")
    tables = list_all_tables(base)

    print("<<<----------------------Checking for Logging Table---------------------->>>")
    meta = check_meta_data("logging_table.csv")

    for table_name in tables:
        df = extracting_data(base + r'\{}'.format(table_name))

        table_name = table_name.split('.')[0]

        if table_name in meta['table'].values:
            print("<<<----------------------Table found---------------------->>>")
            logging_id = meta.loc[meta['table'] == table_name, 'logging_id'].iloc[0] + 1

            print("<<<----------------------Adding new fields---------------------->>>")
            adding_new_columns(df, logging_id)
            meta.loc[meta['table'] == table_name, 'logging_id'] += 1

        else:
            print("<<<----------------------Table not found---------------------->>>")
            logging_id = 1
            new_row = pd.DataFrame({'table': [table_name], 'logging_id': [logging_id]})

            print("<<<----------------------Adding new fields---------------------->>>")
            adding_new_columns(df, logging_id)
            meta = pd.concat([meta, new_row], ignore_index=True)

        schema = 'bronze'

        print("<<<----------------------Writing data into DB---------------------->>>")
        loading_data(df, table_name, schema)

    print("<<<----------------------Updating the logging table---------------------->>>")
    meta.to_csv("logging_table.csv", index = False)

# %%
base_path = r"C:\Users\safwa\OneDrive\Documents\Codes\project\Raw_Data"

# %%
ETL(base_path)
# Out:
# <<<----------------------Fetching All Tables---------------------->>>
# <<<----------------------Checking for Logging Table---------------------->>>
# Extacting Data from C:\Users\safwa\OneDrive\Documents\Codes\project\Raw_Data\Points_Table.csv
# <<<----------------------Table not found---------------------->>>
# <<<----------------------Adding new fields---------------------->>>
# <<<----------------------Writing data into DB---------------------->>>
# <<<----------------------Updating the logging table---------------------->>>

# %%
meta = check_meta_data("logging_table.csv")

# %%
meta
# Out:
#           table  logging_id
# 0  Points_Table           2

# %%
table = 'Points_Table'

# %%
if table in meta['table'].values:
    print("Table found")

# %%
if table in meta['table'].values:
    print("Table found")
    logging_id = meta.loc[meta['table'] == table, 'logging_id'].iloc[0]
    adding_new_columns(df, logging_id)
    meta.loc[meta['table'] == table, 'logging_id'] += 1

else:
    print("Table not found")
    logging_id = 1
    new_row = pd.DataFrame({'table': [table], 'logging_id': [logging_id]})
    adding_new_columns(df, logging_id)
    meta = pd.concat([meta, new_row], ignore_index=True)
# Out:
# Table found

# %%
df
# Out:
#     Season_End_Year             Team  Rk  MP   W   D   L  GF  GA  GD  Pts  \
# 0              1993          Arsenal  10  42  15  11  16  40  38   2   56
# 1              1993      Aston Villa   2  42  21  11  10  57  40  17   74
# 2              1993        Blackburn   4  42  20  11  11  68  46  22   71
# 3              1993          Chelsea  11  42  14  14  14  51  54  -3   56
# 4              1993    Coventry City  15  42  13  13  16  52  57  -5   52
# 5              1993   Crystal Palace  20  42  11  16  15  48  61 -13   49
# 6              1993          Everton  13  42  15   8  19  53  55  -2   53
# 7              1993     Ipswich Town  16  42  12  16  14  50  55  -5   52
# 8              1993     Leeds United  17  42  12  15  15  57  62  -5   51
# 9              1993        Liverpool   6  42  16  11  15  62  55   7   59
# 10             1993  Manchester City   9  42  15  12  15  56  51   5   57
# 11             1993   Manchester Utd   1  42  24  12   6  67  31  36   84
# 12             1993    Middlesbrough  21  42  11  11  20  54  75 -21   44
# 13             1993     Norwich City   3  42  21   9  12  61  65  -4   72
# 14             1993  Nott'ham Forest  22  42  10  10  22  41  62 -21   40
# 15             1993  Oldham Athletic  19  42  13  10  19  63  74 -11   49
# 16             1993              QPR   5  42  17  12  13  63  55   8   63
# 17             1993    Sheffield Utd  14  42  14  10  18  54  53   1   52
# 18             1993   Sheffield Weds   7  42  15  14  13  55  51   4   59
# 19             1993      Southampton  18  42  13  11  18  54  61  -7   50
# 20             1993        Tottenham   8  42  16  11  15  60  66  -6   59
# 21             1993        Wimbledon  12  42  14  12  16  56  55   1   54
#
#                                         Notes  batch_id start_date end_date  \
# 0   → European Cup Winners' Cup via cup win 2         1       None     None
# 1                → UEFA Cup via league finish         1       None     None
# 2                                         NaN         1       None     None
# 3                                         NaN         1       None     None
# 4                                         NaN         1       None     None
# 5                                   Relegated         1       None     None
# 6                                         NaN         1       None     None
# 7                                         NaN         1       None     None
# 8                                         NaN         1       None     None
# 9                                         NaN         1       None     None
# 10                                        NaN         1       None     None
# 11       → Champions League via league finish         1       None     None
# 12                                  Relegated         1       None     None
# 13             → UEFA Cup via league finish 1         1       None     None
# 14                                  Relegated         1       None     None
# 15                                        NaN         1       None     None
# 16                                        NaN         1       None     None
# 17                                        NaN         1       None     None
# 18                                        NaN         1       None     None
# 19                                        NaN         1       None     None
# 20                                        NaN         1       None     None
# 21                                        NaN         1       None     None
#
#    is_active
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# 6       None
# 7       None
# 8       None
# 9       None
# 10      None
# 11      None
# 12      None
# 13      None
# 14      None
# 15      None
# 16      None
# 17      None
# 18      None
# 19      None
# 20      None
# 21      None

# %%
tables = list_all_tables(base_path)

# %%
tables[0].split('.')[0]
# Out:
# 'Points_Table'

# %%
tables = list_all_tables(base_path)
for table_name in tables:
    df = ETL(base_path, table_name)
# Out:
# Extacting Data from C:\Users\safwa\OneDrive\Documents\Codes\project\Raw_Data\1993_season.csv

# %%
df
# Out:
#     Season_End_Year             Team  Rk  MP   W   D   L  GF  GA  GD  Pts  \
# 0              1993          Arsenal  10  42  15  11  16  40  38   2   56
# 1              1993      Aston Villa   2  42  21  11  10  57  40  17   74
# 2              1993        Blackburn   4  42  20  11  11  68  46  22   71
# 3              1993          Chelsea  11  42  14  14  14  51  54  -3   56
# 4              1993    Coventry City  15  42  13  13  16  52  57  -5   52
# 5              1993   Crystal Palace  20  42  11  16  15  48  61 -13   49
# 6              1993          Everton  13  42  15   8  19  53  55  -2   53
# 7              1993     Ipswich Town  16  42  12  16  14  50  55  -5   52
# 8              1993     Leeds United  17  42  12  15  15  57  62  -5   51
# 9              1993        Liverpool   6  42  16  11  15  62  55   7   59
# 10             1993  Manchester City   9  42  15  12  15  56  51   5   57
# 11             1993   Manchester Utd   1  42  24  12   6  67  31  36   84
# 12             1993    Middlesbrough  21  42  11  11  20  54  75 -21   44
# 13             1993     Norwich City   3  42  21   9  12  61  65  -4   72
# 14             1993  Nott'ham Forest  22  42  10  10  22  41  62 -21   40
# 15             1993  Oldham Athletic  19  42  13  10  19  63  74 -11   49
# 16             1993              QPR   5  42  17  12  13  63  55   8   63
# 17             1993    Sheffield Utd  14  42  14  10  18  54  53   1   52
# 18             1993   Sheffield Weds   7  42  15  14  13  55  51   4   59
# 19             1993      Southampton  18  42  13  11  18  54  61  -7   50
# 20             1993        Tottenham   8  42  16  11  15  60  66  -6   59
# 21             1993        Wimbledon  12  42  14  12  16  56  55   1   54
#
#                                         Notes
# 0   → European Cup Winners' Cup via cup win 2
# 1                → UEFA Cup via league finish
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                   Relegated
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11       → Champions League via league finish
# 12                                  Relegated
# 13             → UEFA Cup via league finish 1
# 14                                  Relegated
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN

# %%
df = extracting_data(r"C:\Users\safwa\OneDrive\Documents\Codes\project\Points_Table\1993_season.csv")
# Out:
# Extacting Data from C:\Users\safwa\OneDrive\Documents\Codes\project\Points_Table\1993_season.csv

# %%
df
# Out:
#     Season_End_Year             Team  Rk  MP   W   D   L  GF  GA  GD  Pts  \
# 0              1993          Arsenal  10  42  15  11  16  40  38   2   56
# 1              1993      Aston Villa   2  42  21  11  10  57  40  17   74
# 2              1993        Blackburn   4  42  20  11  11  68  46  22   71
# 3              1993          Chelsea  11  42  14  14  14  51  54  -3   56
# 4              1993    Coventry City  15  42  13  13  16  52  57  -5   52
# 5              1993   Crystal Palace  20  42  11  16  15  48  61 -13   49
# 6              1993          Everton  13  42  15   8  19  53  55  -2   53
# 7              1993     Ipswich Town  16  42  12  16  14  50  55  -5   52
# 8              1993     Leeds United  17  42  12  15  15  57  62  -5   51
# 9              1993        Liverpool   6  42  16  11  15  62  55   7   59
# 10             1993  Manchester City   9  42  15  12  15  56  51   5   57
# 11             1993   Manchester Utd   1  42  24  12   6  67  31  36   84
# 12             1993    Middlesbrough  21  42  11  11  20  54  75 -21   44
# 13             1993     Norwich City   3  42  21   9  12  61  65  -4   72
# 14             1993  Nott'ham Forest  22  42  10  10  22  41  62 -21   40
# 15             1993  Oldham Athletic  19  42  13  10  19  63  74 -11   49
# 16             1993              QPR   5  42  17  12  13  63  55   8   63
# 17             1993    Sheffield Utd  14  42  14  10  18  54  53   1   52
# 18             1993   Sheffield Weds   7  42  15  14  13  55  51   4   59
# 19             1993      Southampton  18  42  13  11  18  54  61  -7   50
# 20             1993        Tottenham   8  42  16  11  15  60  66  -6   59
# 21             1993        Wimbledon  12  42  14  12  16  56  55   1   54
#
#                                         Notes
# 0   → European Cup Winners' Cup via cup win 2
# 1                → UEFA Cup via league finish
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                   Relegated
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11       → Champions League via league finish
# 12                                  Relegated
# 13             → UEFA Cup via league finish 1
# 14                                  Relegated
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN

# %%
def adding_new_columns(dataframe):

# %%
df['batch_id'] = 1

# %%
df['is_active'] = None

# %%
df['start_date'] = None

# %%
df['end_date'] = None

# %%
user = "postgres"
password = "admin"
host = "localhost"
port = "5432"
db = "DWH"

conn = establish_connection_to_database(user, password, host, port, db)

# %%
# converting data to sql 
dataset.to_sql(tableName, conn, schema = schemaName, index = False, if_exists = 'replace')

print("<<<------------------WRITTEN INTO THE DATABASE------------------>>>")
